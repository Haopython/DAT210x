# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.mplot3d import Axes3D

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %% [markdown]
# Load up the wheat seeds dataset into a dataframe. We've stored a copy in the Datasets directory.

# %%
# .. your code here ..
df = pd.read_csv('Datasets/wheat.data')
df.tail()
# Out:
#       id   area  perimeter  compactness  length  width  asymmetry  groove  \
# 205  205  12.19      13.20       0.8783   5.137  2.981      3.631   4.870
# 206  206  11.23      12.88       0.8511   5.140  2.795      4.325   5.003
# 207  207  13.20      13.66       0.8883   5.236  3.232      8.315   5.056
# 208  208  11.84      13.21       0.8521   5.175  2.836      3.598   5.044
# 209  209  12.30      13.34       0.8684   5.243  2.974      5.637   5.063
#
#     wheat_type
# 205   canadian
# 206   canadian
# 207   canadian
# 208   canadian
# 209   canadian

# %% [markdown]
# Create a new 3D subplot using figure `fig`, which we've defined for you below. Use that subplot to draw a 3D scatter plot using the `area`, `perimeter`, and `asymmetry` features. Be sure so use the optional display parameter `c='red'`, and also label your axes:

# %%
fig = plt.figure()

# .. your code here ..
sp = fig.add_subplot(111, projection = '3d')
xs = df['area']
ys = df['perimeter']
zs = df['asymmetry']
sp.set_xlabel('area')
sp.set_ylabel('perimeter')
sp.set_zlabel('asymmetry')
sp.scatter(xs, ys, zs, c = 'r')

# %% [markdown]
# Create another 3D subplot using fig. Then use the subplot to graph a 3D scatter plot of the `width`, `groove`, and `length` features. Be sure so use the optional display parameter `c='green'`, and be sure to label your axes:

# %%
fig = plt.figure()

# .. your code here ..
sp2 = fig.add_subplot(111, projection = '3d')
sp2.set_xlabel('width')
sp2.set_ylabel('groove')
sp2.set_zlabel('length')
sp2.scatter(df['width'], df['groove'], df['length'], c = 'green', marker = '.')

# %%
# Finally, display the graphs:
plt.show()

# %%
#Questions
# Which of the plots were you able to identify two outliers within, that stuck out from the samples?
#Answer: The width versus groove versus length plot can easily identify the outliers. The outliers are at the bottom of the
#plot.
